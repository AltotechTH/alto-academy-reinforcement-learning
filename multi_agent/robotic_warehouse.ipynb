# %%
import time

import numpy as np
import gym # need to install "shimmy>=0.2.1"
from gym import spaces

# pip install rware
import rware

from stable_baselines3 import DQN, PPO
from stable_baselines3.common.env_util import DummyVecEnv, SubprocVecEnv

# %% [markdown]
# ## 1. Explore Environment

# %%
env = gym.make("rware-tiny-2ag-v1") # , sensor_range=3, request_queue_size=6)

# %%
env.n_agents
# Out:
# 2

# %%
env.action_space
# env.observation_space  # Tuple(Box(XX,), Box(XX,))
# Out:
# Tuple(Discrete(5), Discrete(5))

# %%
env.reset()
env.render()
# Out:
# 2024-05-18 07:23:24.315 Python[21324:989235] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/rd/xnkdmhqx0c19zv0s0z9zcc9c0000gn/T/org.python.python.savedState
# True

# %%
actions = env.action_space.sample()
nobs, nreward, ndone, ninfo = env.step(actions)
print(actions, nreward)
env.render()
# Out:
# (4, 4) [0.0, 0.0]
# True

# %% [markdown]
# ## 2. Learning Joint Action Learners (JAL)
# - treating PPO as a joint action learner

# %%
class CentralizedEnv(gym.Env):
    def __init__(self, env):
        super(CentralizedEnv, self).__init__()
        self.env = env
        self.num_agents = self.env.n_agents

        # Combine the observation spaces of all agents
        obs_spaces = self.env.observation_space
        obs_low = np.concatenate([obs_space.low for obs_space in obs_spaces], axis=None)
        obs_high = np.concatenate([obs_space.high for obs_space in obs_spaces], axis=None)
        self.observation_space = spaces.Box(low=obs_low, high=obs_high, dtype=np.float32)

        # Combine the action spaces of all agents
        self.action_space = spaces.MultiDiscrete([self.env.action_space[i].n for i in range(self.num_agents)])

    def step(self, actions):
        actions = np.split(actions, self.num_agents)
        obs, rewards, dones, info = self.env.step(actions)
        obs = np.concatenate(obs, axis=None)
        total_reward = sum(rewards)
        done = all(dones)
        return obs, total_reward, done, info

    def reset(self):
        obs = self.env.reset()
        return np.concatenate(obs, axis=None)

    def render(self, mode='human'):
        return self.env.render(mode=mode)

    def close(self):
        return self.env.close()

# %%
# Initialize the centralized environment
layout = """
.......
...x...
..x.x..
.x...x.
..x.x..
...x...
.g...g.
"""
env = gym.make("rware:rware-tiny-2ag-v1", layout=layout)
# env = gym.make('rware-tiny-2ag-v1')
centralized_env = CentralizedEnv(env)
vec_env = DummyVecEnv([lambda: centralized_env])

# Define the centralized policy (PPO)
centralized_agent = PPO('MlpPolicy', vec_env, verbose=1)

# Train the centralized agent
num_timesteps = int(1e6)
centralized_agent.learn(total_timesteps=num_timesteps)
# Out:
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 2106 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1728        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008204583 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | -0.645      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00206     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.0127      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1615        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009815653 |
# |    clip_fraction        | 0.0974      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.146       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0404     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 0.0062      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1558        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009995309 |
# |    clip_fraction        | 0.0984      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.327       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0107     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 0.00489     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1511        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013415465 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | -0.75       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0238     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0275     |
# |    value_loss           | 0.00158     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1499        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011849176 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | -0.67       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0075     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0255     |
# |    value_loss           | 0.00143     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1497        |
# |    iterations           | 7           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009569073 |
# |    clip_fraction        | 0.0984      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | -0.824      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0586     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 0.000736    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1493        |
# |    iterations           | 8           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010864822 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | -1.31       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0571     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 0.000542    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1482        |
# |    iterations           | 9           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010329879 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.0218      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0171     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 0.00233     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1483        |
# |    iterations           | 10          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010826589 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.226       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0258     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 0.00197     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1478        |
# |    iterations           | 11          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009567287 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0129     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 0.00152     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1462        |
# |    iterations           | 12          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013593701 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | -0.177      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0375     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0252     |
# |    value_loss           | 0.00289     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1458        |
# |    iterations           | 13          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011337941 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.3         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0281     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 0.003       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1461       |
# |    iterations           | 14         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01054635 |
# |    clip_fraction        | 0.0995     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.01      |
# |    explained_variance   | -0.381     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0205    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0204    |
# |    value_loss           | 0.000827   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1459        |
# |    iterations           | 15          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012696916 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0148     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 0.00473     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1461       |
# |    iterations           | 16         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01515126 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.99      |
# |    explained_variance   | 0.46       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0537    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0249    |
# |    value_loss           | 0.00391    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1462        |
# |    iterations           | 17          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.012101701 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00214    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 0.00332     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1464        |
# |    iterations           | 18          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012817053 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.0116      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0211     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0283     |
# |    value_loss           | 0.000591    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1464        |
# |    iterations           | 19          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012574001 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | -1.33       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0437     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0298     |
# |    value_loss           | 0.00043     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1465        |
# |    iterations           | 20          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011195543 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0443     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0211     |
# |    value_loss           | 0.00111     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1465       |
# |    iterations           | 21         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01110323 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.89      |
# |    explained_variance   | 0.184      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0358    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0181    |
# |    value_loss           | 0.00214    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1467        |
# |    iterations           | 22          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012381887 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.0563      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0693     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0293     |
# |    value_loss           | 0.0017      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1462        |
# |    iterations           | 23          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.014908617 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0346     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0228     |
# |    value_loss           | 0.00283     |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1463      |
# |    iterations           | 24        |
# |    time_elapsed         | 33        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0143641 |
# |    clip_fraction        | 0.157     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.84     |
# |    explained_variance   | 0.775     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0406   |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -0.0243   |
# |    value_loss           | 0.00183   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1461        |
# |    iterations           | 25          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014230632 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0398     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0289     |
# |    value_loss           | 0.00143     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1449        |
# |    iterations           | 26          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012780272 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0332     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 0.00196     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1448       |
# |    iterations           | 27         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01327089 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.74      |
# |    explained_variance   | 0.489      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0322    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0287    |
# |    value_loss           | 0.00101    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1446        |
# |    iterations           | 28          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010470245 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0441     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1447        |
# |    iterations           | 29          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.012092709 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0551     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 0.000927    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1448        |
# |    iterations           | 30          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.013181722 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0221     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 0.00259     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1448        |
# |    iterations           | 31          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.014257626 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.657       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0328     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 0.00169     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1449        |
# |    iterations           | 32          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.012910873 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | -0.598      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0411     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0268     |
# |    value_loss           | 0.000589    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1449        |
# |    iterations           | 33          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011639811 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | -0.103      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0494     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0269     |
# |    value_loss           | 0.000424    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1447        |
# |    iterations           | 34          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.014315324 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0183     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 0.00225     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1445        |
# |    iterations           | 35          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.013992511 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0328     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0231     |
# |    value_loss           | 0.00235     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1444         |
# |    iterations           | 36           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0155489035 |
# |    clip_fraction        | 0.172        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.61        |
# |    explained_variance   | 0.269        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00335      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0265      |
# |    value_loss           | 0.00262      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1442        |
# |    iterations           | 37          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.015527232 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.187       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0509     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0267     |
# |    value_loss           | 0.00443     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1437        |
# |    iterations           | 38          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.013741861 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | -0.194      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.051      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0307     |
# |    value_loss           | 0.00114     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1435        |
# |    iterations           | 39          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.013405144 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.453       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0113     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 0.00487     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1433        |
# |    iterations           | 40          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011974055 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0334     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 0.00133     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1432        |
# |    iterations           | 41          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.013652559 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0492     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.025      |
# |    value_loss           | 0.00139     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1432        |
# |    iterations           | 42          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.012217244 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0329     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 0.000248    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1430        |
# |    iterations           | 43          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.014095596 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | -0.665      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0516     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 0.000176    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1430        |
# |    iterations           | 44          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010587846 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0152     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0263     |
# |    value_loss           | 6.84e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1430        |
# |    iterations           | 45          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010516454 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.49       |
# |    explained_variance   | 0.355       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0312     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 0.00242     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1430        |
# |    iterations           | 46          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.012780724 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.49       |
# |    explained_variance   | -0.196      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0301     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0254     |
# |    value_loss           | 0.000452    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1429       |
# |    iterations           | 47         |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.01287746 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.44      |
# |    explained_variance   | 0.408      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0333    |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0205    |
# |    value_loss           | 0.00164    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1424        |
# |    iterations           | 48          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.014240099 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.789       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0285     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0278     |
# |    value_loss           | 0.000911    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1421        |
# |    iterations           | 49          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.013504884 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.41       |
# |    explained_variance   | 0.355       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0134     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.00377     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1418       |
# |    iterations           | 50         |
# |    time_elapsed         | 72         |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01356774 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.32      |
# |    explained_variance   | 0.786      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0397    |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0244    |
# |    value_loss           | 0.00078    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1417        |
# |    iterations           | 51          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.011417148 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0527     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0212     |
# |    value_loss           | 0.00138     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1415        |
# |    iterations           | 52          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.014635998 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.35       |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0445     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0284     |
# |    value_loss           | 0.00121     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1413        |
# |    iterations           | 53          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.013196569 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0435     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 0.00206     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1411        |
# |    iterations           | 54          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.012886101 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0375     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0286     |
# |    value_loss           | 0.00045     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1411        |
# |    iterations           | 55          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.015000094 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0364     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0247     |
# |    value_loss           | 0.000609    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1411        |
# |    iterations           | 56          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.014831618 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.764       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0426     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 0.00177     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1411        |
# |    iterations           | 57          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.014520053 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0118      |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 0.00202     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1411        |
# |    iterations           | 58          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.014696144 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0443     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 0.000942    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1408         |
# |    iterations           | 59           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0149577875 |
# |    clip_fraction        | 0.155        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.27        |
# |    explained_variance   | 0.794        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0521      |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0249      |
# |    value_loss           | 0.00093      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1405        |
# |    iterations           | 60          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.012919344 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.521       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0479     |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0247     |
# |    value_loss           | 0.00209     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1402        |
# |    iterations           | 61          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.015902193 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0399     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0285     |
# |    value_loss           | 0.00136     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1402        |
# |    iterations           | 62          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.013787292 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | 0.609       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0105     |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 0.0028      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1403        |
# |    iterations           | 63          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.013428986 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | -1.31       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0589     |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0288     |
# |    value_loss           | 0.00033     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1403        |
# |    iterations           | 64          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.015294886 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0403     |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 0.00183     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1398       |
# |    iterations           | 65         |
# |    time_elapsed         | 95         |
# |    total_timesteps      | 133120     |
# ...
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 298         |
# |    time_elapsed         | 427         |
# |    total_timesteps      | 610304      |
# | train/                  |             |
# |    approx_kl            | 0.015169602 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0236     |
# |    n_updates            | 2970        |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 0.00208     |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1427      |
# |    iterations           | 299       |
# |    time_elapsed         | 428       |
# |    total_timesteps      | 612352    |
# | train/                  |           |
# |    approx_kl            | 0.0239407 |
# |    clip_fraction        | 0.116     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.664    |
# |    explained_variance   | 0.731     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0342   |
# |    n_updates            | 2980      |
# |    policy_gradient_loss | -0.0213   |
# |    value_loss           | 0.0037    |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 300         |
# |    time_elapsed         | 430         |
# |    total_timesteps      | 614400      |
# | train/                  |             |
# |    approx_kl            | 0.018059012 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0365     |
# |    n_updates            | 2990        |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 0.00518     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 301         |
# |    time_elapsed         | 431         |
# |    total_timesteps      | 616448      |
# | train/                  |             |
# |    approx_kl            | 0.027587974 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0803     |
# |    n_updates            | 3000        |
# |    policy_gradient_loss | -0.0322     |
# |    value_loss           | 0.00321     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 302         |
# |    time_elapsed         | 433         |
# |    total_timesteps      | 618496      |
# | train/                  |             |
# |    approx_kl            | 0.014831605 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.723      |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0407     |
# |    n_updates            | 3010        |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 0.00397     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 303         |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 620544      |
# | train/                  |             |
# |    approx_kl            | 0.016311482 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.898      |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0444     |
# |    n_updates            | 3020        |
# |    policy_gradient_loss | -0.0238     |
# |    value_loss           | 0.0018      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 304         |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.011475519 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.797      |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0442     |
# |    n_updates            | 3030        |
# |    policy_gradient_loss | -0.0219     |
# |    value_loss           | 0.00307     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1427       |
# |    iterations           | 305        |
# |    time_elapsed         | 437        |
# |    total_timesteps      | 624640     |
# | train/                  |            |
# |    approx_kl            | 0.01757256 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.727     |
# |    explained_variance   | 0.886      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0294    |
# |    n_updates            | 3040       |
# |    policy_gradient_loss | -0.0239    |
# |    value_loss           | 0.00289    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 306         |
# |    time_elapsed         | 438         |
# |    total_timesteps      | 626688      |
# | train/                  |             |
# |    approx_kl            | 0.010819305 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.605      |
# |    explained_variance   | 0.779       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.04       |
# |    n_updates            | 3050        |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 0.00381     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 307         |
# |    time_elapsed         | 440         |
# |    total_timesteps      | 628736      |
# | train/                  |             |
# |    approx_kl            | 0.013166966 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.705      |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0397     |
# |    n_updates            | 3060        |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 0.00357     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 308         |
# |    time_elapsed         | 441         |
# |    total_timesteps      | 630784      |
# | train/                  |             |
# |    approx_kl            | 0.019070163 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0284     |
# |    n_updates            | 3070        |
# |    policy_gradient_loss | -0.0274     |
# |    value_loss           | 0.00287     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 309         |
# |    time_elapsed         | 443         |
# |    total_timesteps      | 632832      |
# | train/                  |             |
# |    approx_kl            | 0.018795434 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0439     |
# |    n_updates            | 3080        |
# |    policy_gradient_loss | -0.0267     |
# |    value_loss           | 0.00138     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 310         |
# |    time_elapsed         | 444         |
# |    total_timesteps      | 634880      |
# | train/                  |             |
# |    approx_kl            | 0.021003872 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0118     |
# |    n_updates            | 3090        |
# |    policy_gradient_loss | -0.0254     |
# |    value_loss           | 0.00411     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 311         |
# |    time_elapsed         | 446         |
# |    total_timesteps      | 636928      |
# | train/                  |             |
# |    approx_kl            | 0.019147817 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.696      |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0304      |
# |    n_updates            | 3100        |
# |    policy_gradient_loss | -0.0242     |
# |    value_loss           | 0.00258     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 312         |
# |    time_elapsed         | 447         |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.021335049 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.747      |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0607     |
# |    n_updates            | 3110        |
# |    policy_gradient_loss | -0.0239     |
# |    value_loss           | 0.00237     |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 21
#      19 # Train the centralized agent
#      20 num_timesteps = int(1e6)
# ---> 21 centralized_agent.learn(total_timesteps=num_timesteps)
#
# File ~/Desktop/AltoTech/codebases/alto-academy-reinforcement-learning/env/lib/python3.9/site-packages/stable_baselines3/ppo/ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File ~/Desktop/AltoTech/codebases/alto-academy-reinforcement-learning/env/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:281, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     278         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     279         self.logger.dump(step=self.num_timesteps)
# --> 281     self.train()
#     283 callback.on_training_end()
#     285 return self
#
# File ~/Desktop/AltoTech/codebases/alto-academy-reinforcement-learning/env/lib/python3.9/site-packages/stable_baselines3/ppo/ppo.py:210, in PPO.train(self)
#     207 if self.use_sde:
#     208     self.policy.reset_noise(self.batch_size)
# --> 210 values, log_prob, entropy = self.policy.evaluate_actions(rollout_data.observations, actions)
#     211 values = values.flatten()
#     212 # Normalize advantage
#
# File ~/Desktop/AltoTech/codebases/alto-academy-reinforcement-learning/env/lib/python3.9/site-packages/stable_baselines3/common/policies.py:700, in ActorCriticPolicy.evaluate_actions(self, obs, actions)
#     698     latent_vf = self.mlp_extractor.forward_critic(vf_features)
#     699 distribution = self._get_action_dist_from_latent(latent_pi)
# --> 700 log_prob = distribution.log_prob(actions)
#     701 values = self.value_net(latent_vf)
#     702 entropy = distribution.entropy()
#
# File ~/Desktop/AltoTech/codebases/alto-academy-reinforcement-learning/env/lib/python3.9/site-packages/stable_baselines3/common/distributions.py:348, in MultiCategoricalDistribution.log_prob(self, actions)
#     345 def log_prob(self, actions: th.Tensor) -> th.Tensor:
#     346     # Extract each discrete action and compute log prob for their respective distributions
#     347     return th.stack(
# --> 348         [dist.log_prob(action) for dist, action in zip(self.distribution, th.unbind(actions, dim=1))], dim=1
#     349     ).sum(dim=1)
#
# File ~/Desktop/AltoTech/codebases/alto-academy-reinforcement-learning/env/lib/python3.9/site-packages/stable_baselines3/common/distributions.py:348, in <listcomp>(.0)
#     345 def log_prob(self, actions: th.Tensor) -> th.Tensor:
#     346     # Extract each discrete action and compute log prob for their respective distributions
#     347     return th.stack(
# --> 348         [dist.log_prob(action) for dist, action in zip(self.distribution, th.unbind(actions, dim=1))], dim=1
#     349     ).sum(dim=1)
#
# File ~/Desktop/AltoTech/codebases/alto-academy-reinforcement-learning/env/lib/python3.9/site-packages/torch/distributions/categorical.py:123, in Categorical.log_prob(self, value)
#     121 def log_prob(self, value):
#     122     if self._validate_args:
# --> 123         self._validate_sample(value)
#     124     value = value.long().unsqueeze(-1)
#     125     value, log_pmf = torch.broadcast_tensors(value, self.logits)
#
# File ~/Desktop/AltoTech/codebases/alto-academy-reinforcement-learning/env/lib/python3.9/site-packages/torch/distributions/distribution.py:298, in Distribution._validate_sample(self, value)
#     296     return
#     297 assert support is not None
# --> 298 valid = support.check(value)
#     299 if not valid.all():
#     300     raise ValueError(
#     301         "Expected value argument "
#     302         f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#     305         f"but found invalid values:\n{value}"
#     306     )
#
# File ~/Desktop/AltoTech/codebases/alto-academy-reinforcement-learning/env/lib/python3.9/site-packages/torch/distributions/constraints.py:257, in _IntegerInterval.check(self, value)
#     256 def check(self, value):
# --> 257     return (value % 1 == 0) & (self.lower_bound <= value) & (value <= self.upper_bound)
#
# KeyboardInterrupt:

# %%
# Evaluate the trained centralized agent
def evaluate_centralized_agent(env, agent, num_episodes=10):
    episode_rewards = []
    for episode in range(num_episodes):
        obs = env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = agent.predict(obs)
            obs, reward, done, _ = env.step(action)
            total_reward += reward
        episode_rewards.append(total_reward)
    return episode_rewards

# Run the evaluation
episode_rewards = evaluate_centralized_agent(centralized_env, centralized_agent, num_episodes=100)
print(f"Average rewards per episode: {np.mean(episode_rewards)}")
# Out:
# Average rewards per episode: 0.66

# %%
# Render the environment with trained centralized agent
obs = centralized_env.reset()
done = False

while not done:
    action, _ = centralized_agent.predict(obs)
    obs, reward, done, _ = centralized_env.step(action)
    centralized_env.render()
# centralized_env.close()
