# %%
import time

import numpy as np
import gym # need to install "shimmy>=0.2.1"
from gym import spaces

# pip install lbforaging
import lbforaging  # need to install "pyglet<2" (source: https://github.com/semitable/lb-foraging/issues/23)

from stable_baselines3 import DQN, PPO
from stable_baselines3.common.env_util import DummyVecEnv, SubprocVecEnv

# %% [markdown]
# ## 1. Explore environment

# %%
# Initialize the environment
env = gym.make('Foraging-8x8-4p-8f-v2')
obs = env.reset()
# Out:
# /Users/thakorns/Desktop/AltoTech/codebases/alto-academy-reinforcement-learning/env/lib/python3.9/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(

# %%
actions = env.action_space.sample()
actions
# Out:
# (4, 0, 2, 2)

# %%
nobs, nreward, ndone, ninfo = env.step(actions)
nobs, nreward, ndone, ninfo
# Out:
# ((array([ 1.,  2.,  2.,  2.,  6.,  2.,  3.,  1.,  2.,  4.,  3.,  1.,  6.,
#           1.,  1.,  6.,  6.,  1., -1., -1.,  0., -1., -1.,  0.,  6.,  5.,
#           1.,  6.,  0.,  1.,  7.,  3.,  1.,  7.,  2.,  1.], dtype=float32),
#   array([ 1.,  2.,  2.,  2.,  6.,  2.,  3.,  1.,  2.,  4.,  3.,  1.,  6.,
#           1.,  1.,  6.,  6.,  1., -1., -1.,  0., -1., -1.,  0.,  6.,  0.,
#           1.,  6.,  5.,  1.,  7.,  3.,  1.,  7.,  2.,  1.], dtype=float32),
#   array([ 1.,  2.,  2.,  2.,  6.,  2.,  3.,  1.,  2.,  4.,  3.,  1.,  6.,
#           1.,  1.,  6.,  6.,  1., -1., -1.,  0., -1., -1.,  0.,  7.,  3.,
#           1.,  6.,  5.,  1.,  6.,  0.,  1.,  7.,  2.,  1.], dtype=float32),
#   array([ 1.,  2.,  2.,  2.,  6.,  2.,  3.,  1.,  2.,  4.,  3.,  1.,  6.,
#           1.,  1.,  6.,  6.,  1., -1., -1.,  0., -1., -1.,  0.,  7.,  2.,
#           1.,  6.,  5.,  1.,  6.,  0.,  1.,  7.,  3.,  1.], dtype=float32)),
#  [0, 0, 0, 0],
#  [False, False, False, False],
#  {})

# %%
actions = env.action_space.sample()
nobs, nreward, ndone, ninfo = env.step(actions)
env.render()
# Out:
# True

# %% [markdown]
# ## 2. Learning Decentralized

# %%
class SingleAgentEnv(gym.Env):
    def __init__(self, env, agent_id):
        super(SingleAgentEnv, self).__init__()
        self.env = env
        self.agent_id = agent_id
        self.action_space = self.env.action_space[agent_id]
        self.observation_space = self.env.observation_space[agent_id]

    def step(self, action):
        actions = [0] * self.env.n_agents  # Default actions (0) for all agents
        actions[self.agent_id] = action    # Assign the agent's action
        obs, rewards, dones, info = self.env.step(actions)
        return obs[self.agent_id], rewards[self.agent_id], dones[self.agent_id], info

    def reset(self):
        obs = self.env.reset()
        return obs[self.agent_id]

    def render(self, mode='human'):
        return self.env.render(mode=mode)

    def close(self):
        return self.env.close()

# %%
# Initialize the environment
env = gym.make('Foraging-8x8-2p-4f-v2', max_episode_steps=500, normalize_reward=False)
num_agents = env.n_agents

# Create individual environments for each agent
agent_envs = [SingleAgentEnv(env, i) for i in range(num_agents)]
vec_envs = [DummyVecEnv([lambda: agent_env]) for agent_env in agent_envs]

# Define individual policies (Q-Learning) for each agent
agents = [DQN('MlpPolicy', vec_env, verbose=1) for vec_env in vec_envs]

# Train each agent independently
num_timesteps = int(1e5)
for i, agent in enumerate(agents):
    print(f"Training agent {i + 1}/{num_agents}")
    agent.learn(total_timesteps=num_timesteps)
# Out:
# Using cpu device
# Using cpu device
# Training agent 1/2
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 9537     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1516     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 9790     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3516     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 9727     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5516     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.301    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 9699     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7359     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.179    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 9703     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8647     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 9687     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10647    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 9760     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12497    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 9695     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 14497    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 9709     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16025    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 9720     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17890    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 9725     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 9720     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 21452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 9751     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 23215    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 9762     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 25136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 9771     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 26826    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 9773     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 28171    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 9782     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 30171    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 9783     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 31462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 9787     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 33445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 9791     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 34930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 9792     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 36236    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 9792     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 37826    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 9791     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 39409    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 9794     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 41294    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 9793     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 42524    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 9796     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 44195    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 9793     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 45874    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 9798     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 47544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 9795     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 49544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 9158     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 51544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00483  |
# |    n_updates        | 385      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 8509     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 53544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00232  |
# |    n_updates        | 885      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 7988     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 55544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00145  |
# |    n_updates        | 1385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 7560     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 57544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00261  |
# |    n_updates        | 1885     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 7167     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 59544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000707 |
# |    n_updates        | 2385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 6790     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 61544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000704 |
# |    n_updates        | 2885     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 6471     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 63544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000271 |
# |    n_updates        | 3385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 6234     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 65544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000602 |
# |    n_updates        | 3885     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 6039     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 67544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000491 |
# |    n_updates        | 4385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 5861     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 69544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000694 |
# |    n_updates        | 4885     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 5704     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 71544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000222 |
# |    n_updates        | 5385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 5557     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 73544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000208 |
# |    n_updates        | 5885     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 5434     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 75544    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000327 |
# |    n_updates        | 6385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 5334     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 77229    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000441 |
# |    n_updates        | 6807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 5227     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 79229    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000374 |
# |    n_updates        | 7307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 5128     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 81229    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000206 |
# |    n_updates        | 7807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 5042     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 83229    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000242 |
# |    n_updates        | 8307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 4956     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 85229    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00017  |
# |    n_updates        | 8807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 4872     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 87229    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000397 |
# |    n_updates        | 9307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 4776     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 89229    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000323 |
# |    n_updates        | 9807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 4700     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 91229    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000262 |
# |    n_updates        | 10307    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 4642     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 93229    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.103    |
# |    n_updates        | 10807    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 4592     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 95229    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.105    |
# |    n_updates        | 11307    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 4546     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 97182    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000173 |
# |    n_updates        | 11795    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 4501     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 99182    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000447 |
# |    n_updates        | 12295    |
# ----------------------------------
# Training agent 2/2
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 10613    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1700     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.701    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 10180    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3146     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 10179    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4824     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 10209    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6644     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.233    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 10183    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8073     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.053    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 10167    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9968     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 10182    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11813    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 10189    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 10173    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 14800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 10183    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16698    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 10137    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18064    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 10146    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19859    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 10143    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 21234    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 10145    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 22801    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 10154    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 24456    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 10162    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 26225    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 10155    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 27919    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 10150    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 29502    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 10147    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 31143    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 10154    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 32410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 10144    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 33996    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 10142    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 35519    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 10142    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 37216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 10142    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 38186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 10140    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 39607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 10143    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 41360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 10144    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 43155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 10133    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 44847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 10139    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 46689    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 10138    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 48162    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 10141    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 49609    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 9415     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 51609    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00429  |
# |    n_updates        | 402      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 8641     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 53609    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00196  |
# |    n_updates        | 902      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 8066     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 55609    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00198  |
# |    n_updates        | 1402     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 7503     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 57609    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00182  |
# |    n_updates        | 1902     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 7108     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 59609    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00139  |
# |    n_updates        | 2402     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 6712     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 61609    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000358 |
# |    n_updates        | 2902     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 6421     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 63609    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000485 |
# |    n_updates        | 3402     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 6173     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 65609    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000403 |
# |    n_updates        | 3902     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 5971     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 67609    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000337 |
# |    n_updates        | 4402     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 5767     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 69578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000785 |
# |    n_updates        | 4894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 5615     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 71578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000472 |
# |    n_updates        | 5394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 5475     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 73578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000613 |
# |    n_updates        | 5894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 5352     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 75578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000857 |
# |    n_updates        | 6394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 5218     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 77578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000338 |
# |    n_updates        | 6894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 5122     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 79578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00042  |
# |    n_updates        | 7394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 5030     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 81578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000628 |
# |    n_updates        | 7894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 4928     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 83578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00063  |
# |    n_updates        | 8394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 4859     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 85578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000236 |
# |    n_updates        | 8894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 4789     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 87578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000345 |
# |    n_updates        | 9394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 4719     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 89578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00021  |
# |    n_updates        | 9894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 4640     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 91578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00039  |
# |    n_updates        | 10394    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 4580     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 93578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000212 |
# |    n_updates        | 10894    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 4526     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 95578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000443 |
# |    n_updates        | 11394    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 4468     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 97578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000187 |
# |    n_updates        | 11894    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 4405     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 99578    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000274 |
# |    n_updates        | 12394    |
# ----------------------------------

# %%
# Evaluate the trained agents
def evaluate_agents(env, agents, num_episodes=10):
    episode_rewards = np.zeros((num_episodes, num_agents))
    for episode in range(num_episodes):
        obs = env.reset()
        done = [False] * num_agents
        while not all(done):
            actions = [agents[i].predict(obs[i])[0] for i in range(num_agents)]
            obs, rewards, done, _ = env.step(actions)
            for i in range(num_agents):
                episode_rewards[episode, i] += rewards[i]
    return episode_rewards

# Run the evaluation
episode_rewards = evaluate_agents(env, agents, num_episodes=100)
print(f"Average rewards per episode: {np.mean(episode_rewards, axis=0)}")
# Out:
# Average rewards per episode: [2.17 2.05]

# %%
# Render the environment with trained agents
env = gym.make('Foraging-8x8-2p-4f-v2', max_episode_steps=1000, normalize_reward=False)
obs = env.reset()
done = [False] * num_agents

while not all(done):
    actions = [agents[i].predict(obs[i])[0] for i in range(num_agents)]
    obs, rewards, done, _ = env.step(actions)
    env.render()
    time.sleep(0.01)
# env.close()

# %% [markdown]
# ## 3. Learning Centralized

# %%
class CentralizedEnv(gym.Env):
    def __init__(self, env):
        super(CentralizedEnv, self).__init__()
        self.env = env
        # Combine the observation spaces of all agents
        obs_space = self.env.observation_space[0]
        low = np.repeat(obs_space.low, self.env.n_agents, axis=0)
        high = np.repeat(obs_space.high, self.env.n_agents, axis=0)
        self.observation_space = spaces.Box(low=low, high=high, dtype=obs_space.dtype)
        
        # Action space will be a tuple of action spaces of all agents
        self.action_space = spaces.MultiDiscrete([self.env.action_space[i].n for i in range(self.env.n_agents)])

    def step(self, actions):
        actions = np.split(actions, self.env.n_agents)
        obs, rewards, dones, info = self.env.step(actions)
        obs = np.concatenate(obs, axis=0)
        return obs, np.sum(rewards), np.all(dones), info

    def reset(self):
        obs = self.env.reset()
        return np.concatenate(obs, axis=0)

    def render(self, mode='human'):
        return self.env.render(mode=mode)

    def close(self):
        return self.env.close()

# %%
# Initialize the centralized environment
env = gym.make('Foraging-8x8-2p-4f-v2', max_episode_steps=500, normalize_reward=False)
centralized_env = CentralizedEnv(env)
vec_env = DummyVecEnv([lambda: centralized_env])

# Define the centralized policy (PPO)
centralized_agent = PPO('MlpPolicy', vec_env, verbose=1)

# Train the centralized agent
num_timesteps = int(1e5)
centralized_agent.learn(total_timesteps=num_timesteps)
# Out:
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 2552 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2001        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011027468 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.433       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.02       |
# |    value_loss           | 0.385       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1867        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013006421 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.318       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0338      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0193     |
# |    value_loss           | 0.164       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1769        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010453848 |
# |    clip_fraction        | 0.0948      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.34        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0806      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 0.314       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1747        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012412066 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0312     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0217     |
# |    value_loss           | 0.106       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1731        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010915724 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0519      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 0.0822      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1725       |
# |    iterations           | 7          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00927262 |
# |    clip_fraction        | 0.0983     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.54      |
# |    explained_variance   | 0.709      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0128     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0204    |
# |    value_loss           | 0.234      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1720        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011557314 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0174     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 0.114       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1719       |
# |    iterations           | 9          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01083908 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.51      |
# |    explained_variance   | 0.636      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00587   |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0223    |
# |    value_loss           | 0.202      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1716        |
# |    iterations           | 10          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.014537882 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0222     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0292     |
# |    value_loss           | 0.0861      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1716        |
# |    iterations           | 11          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011496214 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | 0.691       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0285      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 0.182       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1712        |
# |    iterations           | 12          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012002422 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0443      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0224     |
# |    value_loss           | 0.198       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1710         |
# |    iterations           | 13           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0124864625 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.49        |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0383       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0261      |
# |    value_loss           | 0.107        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1708        |
# |    iterations           | 14          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014175996 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00749    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 0.245       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1698        |
# |    iterations           | 15          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.013203944 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0473      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 0.196       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1696        |
# |    iterations           | 16          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014668677 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.483       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.812       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 0.507       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1693        |
# |    iterations           | 17          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.013241183 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0641      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0244     |
# |    value_loss           | 0.232       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 18          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.015959127 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.103       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0296     |
# |    value_loss           | 0.185       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 19          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.015891366 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0645      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0272     |
# |    value_loss           | 0.234       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 20          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011939246 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0472      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0232     |
# |    value_loss           | 0.329       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1686       |
# |    iterations           | 21         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01530862 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.39      |
# |    explained_variance   | 0.722      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0812     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0261    |
# |    value_loss           | 0.35       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1684        |
# |    iterations           | 22          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.015615556 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | 0.55        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0478      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0287     |
# |    value_loss           | 0.248       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1682       |
# |    iterations           | 23         |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01816757 |
# |    clip_fraction        | 0.199      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.38      |
# |    explained_variance   | 0.77       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.117      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0277    |
# |    value_loss           | 0.248      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1682        |
# |    iterations           | 24          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013594484 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.36       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.116       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0268     |
# |    value_loss           | 0.226       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1682         |
# |    iterations           | 25           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0132861445 |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.32        |
# |    explained_variance   | 0.46         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.159        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.021       |
# |    value_loss           | 0.46         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1683        |
# |    iterations           | 26          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013723087 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.32       |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0665      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 0.39        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1684        |
# |    iterations           | 27          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.012743283 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.32       |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0759      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0232     |
# |    value_loss           | 0.511       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1685        |
# |    iterations           | 28          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.017069269 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.34       |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.184       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 0.593       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 29          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.013834775 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.603       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.592       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 1.02        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1687        |
# |    iterations           | 30          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.013723856 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.28       |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.118       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0241     |
# |    value_loss           | 0.99        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1687        |
# |    iterations           | 31          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.013406349 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0831      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 0.646       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1684        |
# |    iterations           | 32          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.017617695 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.32       |
# |    explained_variance   | 0.684       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0907      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.028      |
# |    value_loss           | 0.328       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1681        |
# |    iterations           | 33          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.012513926 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.427       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0208     |
# |    value_loss           | 0.803       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1681        |
# |    iterations           | 34          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.014360564 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0839      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0281     |
# |    value_loss           | 0.807       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1680        |
# |    iterations           | 35          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.013170358 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.414       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0219     |
# |    value_loss           | 0.737       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1678        |
# |    iterations           | 36          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013364603 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.325       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0225     |
# |    value_loss           | 0.933       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1677        |
# |    iterations           | 37          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.013805472 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.289       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 1.31        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1675        |
# |    iterations           | 38          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.013499337 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.547       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.885       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0212     |
# |    value_loss           | 1.75        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1676        |
# |    iterations           | 39          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.014044314 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.684       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0518      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 0.47        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1677        |
# |    iterations           | 40          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.014581205 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.671       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0225     |
# |    value_loss           | 0.971       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1678        |
# |    iterations           | 41          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.018371165 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.102       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0294     |
# |    value_loss           | 0.694       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1677       |
# |    iterations           | 42         |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.02438682 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.14      |
# |    explained_variance   | 0.764      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.126      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0266    |
# |    value_loss           | 0.63       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1673       |
# |    iterations           | 43         |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.01629656 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.23      |
# |    explained_variance   | 0.644      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.261      |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0188    |
# |    value_loss           | 0.842      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1672        |
# |    iterations           | 44          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.015049573 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.19        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0224     |
# |    value_loss           | 1.13        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1666        |
# |    iterations           | 45          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.015579468 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.389       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0309     |
# |    value_loss           | 0.886       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1662        |
# |    iterations           | 46          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.015342759 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.64        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.735       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0207     |
# |    value_loss           | 1.2         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1660        |
# |    iterations           | 47          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.014513206 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.386       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0206     |
# |    value_loss           | 1.34        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1658        |
# |    iterations           | 48          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.013932468 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.637       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0211     |
# |    value_loss           | 1.46        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1654        |
# |    iterations           | 49          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.019532597 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 0.589       |
# -----------------------------------------

# %%
# Evaluate the trained centralized agent
def evaluate_centralized_agent(env, agent, num_episodes=10):
    episode_rewards = []
    for episode in range(num_episodes):
        obs = env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = agent.predict(obs)
            obs, reward, done, _ = env.step(action)
            total_reward += reward
        episode_rewards.append(total_reward)
    return episode_rewards

# Run the evaluation
episode_rewards = evaluate_centralized_agent(centralized_env, centralized_agent, num_episodes=100)
print(f"Average rewards per episode: {np.mean(episode_rewards)}")
# Out:
# Average rewards per episode: 11.13

# %%
# Render the environment with trained centralized agent
obs = centralized_env.reset()
done = False

while not done:
    action, _ = centralized_agent.predict(obs)
    obs, reward, done, _ = centralized_env.step(action)
    centralized_env.render()
# centralized_env.close()
